# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title("Sine Wave Plot")
plt.xlabel("X axis")
plt.ylabel("sin(x)")
plt.grid(True)

plt.show()
